# %% [markdown]
# # Programming Assignment: Анализ изображений
#
# Задача заключается в том, чтобы применить предобученную на imagenet нейронную сеть на практической задаче классификации автомобилей.
#
# Учиться применять нейронные сети для анализа изображений мы будем на библиотеке TensorFlow. Это известный опенсорсный проект, разработанный инженерами Google Brain Team. Подробнее почитать о TensorFlow можно на официальном сайте, на [гитхабе](https://github.com/tensorflow/tensorflow) или [на хабре](https://habrahabr.ru/post/270543/).

# %% [markdown]
# ### Установка окружения
#
# В первую очередь нам будет необходимо установить **TensorFlow**.
# * [Инструкции по установке на сайте](https://www.tensorflow.org/versions/r0.10/get_started/os_setup.html#download-and-setup).
# * Если есть опыт работы с Docker, то можно воспользоваться готовым [докер-контейнером с тензорфлоу](https://www.tensorflow.org/versions/r0.10/get_started/os_setup.html#docker-installation).
#
# **Важно!** Если вы пользователь Windows, то уставить tensorflow напрямую, к сожалению, не получится:
#
# * для пользователей Windows 10 (и выше) нужно использовать **Docker** ([ссылка на дистрибутив](https://www.docker.com/products/docker#/windows));
# * если у вас Windows старше версии 10, то и вариант с докером не подойдет — он не установится. В таком случае советуем установить линукс на локальную машину как еще одну операционную систему (поможет избежать страданий в будущем при работе с некоторыми библиотеками для ML).
#
# Если же поставить Tensorflow на вашу машину никак не получается, мы предлагаем воспользоваться одним из облачных сервисов, в который необходимо установить линукс-образ. Самые популярные облачные сервисы [AWS](https://aws.amazon.com) и [DigitalOcean](http://digitalocean.com) предоставляют бесплатные инстансы (имейте в виду, что для того, чтобы ими воспользоваться, нужно будет привязать кредитную карту).
#
# Чтобы освоить компьютерное зрение (или другие интересные задачи из области ML и AI), так или иначе придётся научиться работать с библиотеками нейронных сетей, линуксом и виртуальными серверами. Например, для более масштабных практических задач, крайне необходимы сервера с GPU, а с ними уже локально работать не получиться.
#
# Тем не менее, мы понимаем, что в силу временных ограничений курса кто-то может успеть установить TensorFlow. Поэтому мы сделали пункты 1 и 2 необязательными. На оценку они не повлияют — можете сразу переходить к третьему пункту.
#
# Помимо tensorflow, потребуется библиотека **`scipy`**. Если вы уже работали с Anaconda и/или выполняли задания в нашей специализации, то она должна присутствовать.

# %% [markdown]
# ## Данные
#
# Скачать данные нужно тут: https://yadi.sk/d/6m_KbM4HvmLfs
#
# Данные это часть выборки _Cars Dataset_ ([link](http://ai.stanford.edu/~jkrause/cars/car_dataset.html)). Исходный датасет содержит 16,185 изображений автомобилей, принадлежащих к 196 классам. Данные разделены на 8,144 тренировочных и 8,041 тестовых изображений, при этом каждый класс разделён приблизительно поровну между тестом и трейном. Все классы уровня параметров _Марка_, _Год_, _Модель_ и др. (например, _2012 Tesla Model S or 2012 BMW M3 coupe_).
#
# В нашем же случае в `train` 204 изображения, и в `test` — 202 изображения.
#
# ## Что делать
#
# Помимо данных, потребуется скачать:
#
# * [код](https://github.com/ton4eg/coursera_pa),
# * веса модели [по ссылке](https://yadi.sk/d/9-3kXyxRvnBwh)
#
# Положите данные, код и модель в одну папку. У вас должна получиться такая структура:
#
# ```
# /assignment-computer-vision/
# |
# |-- test              # папки
# |    `---- ...        # с
# |-- train             # картинками
# |    `---- ...
# |
# |-- class_names.txt   # имена классов, номер строки соответствует id класса
# |-- results.txt       # соответствие имя картинки — id класса
# |-- vgg16_weights.npz # веса модели в формате tensorflow
# |
# |-- vgg16.py            # основной скрипт
# |-- imagenet_classes.py
# |
# `-- beach.jpg         # картиночка с пляжем
# ```

# %% [markdown]
# ## Запуск из Docker gcr.io/tensorflow/tensorflow
# * докер запускает Jupyter Notebook с рабочей папкой /notebooks
# * в докере не хватает библиотек sklearn и Pillow
#
# Рекомендуется запускать докер командой
#
# docker run -it -p 127.0.0.1:8888:8888 -v $PWD:/notebooks gcr.io/tensorflow/tensorflow
#
# при запуске из папки, где лежит данный ноутбук и все нужные файлы, они сразу окажутся в рабочей папке Jupyter
# Notebook.
#
# Следующие две ячейки содержат команды, доустанавливающие нужные библиотеки.

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.22.3)
# Requirement already satisfied: scipy>=0.19.1 in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (2.2.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=ce0b261ba8bf8ac69df26f80c3b0eaa912a5546735cb7cdf439eb390b777cfde
#   Stored in directory: /Users/dashakaravaieva/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# !pip install -U pillow
# Out:
# Requirement already satisfied: pillow in /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages (8.4.0)
# Collecting pillow
#   Downloading Pillow-9.1.0-cp39-cp39-macosx_10_9_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 1.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# catboost 0.26.1 requires graphviz, which is not installed.
# catboost 0.26.1 requires plotly, which is not installed.
# streamlit 1.3.0 requires click<8.0,>=7.0, but you have click 8.0.3 which is incompatible.
# Successfully installed pillow-9.1.0

# %% [markdown]
# Импортируем всё, что нам нужно для работы.

# %%
# !jupyter notebook --debug
# Out:
# [D 12:58:11.716 NotebookApp] Searching ['/Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2', '/Users/dashakaravaieva/.jupyter', '/Users/dashakaravaieva/opt/anaconda3/etc/jupyter', '/usr/local/etc/jupyter', '/etc/jupyter'] for config files
# [D 12:58:11.716 NotebookApp] Looking for jupyter_config in /etc/jupyter
# [D 12:58:11.716 NotebookApp] Looking for jupyter_config in /usr/local/etc/jupyter
# [D 12:58:11.716 NotebookApp] Looking for jupyter_config in /Users/dashakaravaieva/opt/anaconda3/etc/jupyter
# [D 12:58:11.716 NotebookApp] Looking for jupyter_config in /Users/dashakaravaieva/.jupyter
# [D 12:58:11.717 NotebookApp] Looking for jupyter_config in /Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2
# [D 12:58:11.717 NotebookApp] Looking for jupyter_notebook_config in /etc/jupyter
# [D 12:58:11.717 NotebookApp] Looking for jupyter_notebook_config in /usr/local/etc/jupyter
# [D 12:58:11.717 NotebookApp] Looking for jupyter_notebook_config in /Users/dashakaravaieva/opt/anaconda3/etc/jupyter
# [D 12:58:11.718 NotebookApp] Loaded config file: /Users/dashakaravaieva/opt/anaconda3/etc/jupyter/jupyter_notebook_config.json
# [D 12:58:11.718 NotebookApp] Looking for jupyter_notebook_config in /Users/dashakaravaieva/.jupyter
# [D 12:58:11.718 NotebookApp] Looking for jupyter_notebook_config in /Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2
# [D 12:58:11.724 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/etc/jupyter/jupyter_notebook_config.json
# [D 12:58:11.724 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/usr/local/etc/jupyter/jupyter_notebook_config.json
# [D 12:58:11.725 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/jupyter_notebook_config.d/jupyterlab.json
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/jupyter_notebook_config.json
# [D 12:58:11.725 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/Users/dashakaravaieva/.jupyter/jupyter_notebook_config.json
# [I 2022-05-10 12:58:11.998 LabApp] JupyterLab extension loaded from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/jupyterlab
# [I 2022-05-10 12:58:11.998 LabApp] JupyterLab application directory is /Users/dashakaravaieva/opt/anaconda3/share/jupyter/lab
# [I 12:58:12.001 NotebookApp] The port 8888 is already in use, trying another port.
# [I 12:58:12.003 NotebookApp] Serving notebooks from local directory: /Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2
# [I 12:58:12.003 NotebookApp] Jupyter Notebook 6.4.5 is running at:
# [I 12:58:12.003 NotebookApp] http://localhost:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
# [I 12:58:12.003 NotebookApp]  or http://127.0.0.1:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
# [I 12:58:12.003 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 12:58:12.007 NotebookApp]
#
#     To access the notebook, open this file in a browser:
#         file:///Users/dashakaravaieva/Library/Jupyter/runtime/nbserver-71187-open.html
#     Or copy and paste one of these URLs:
#         http://localhost:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
#      or http://127.0.0.1:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
# [D 12:58:13.240 NotebookApp] Accepting token-authenticated connection from ::1
# [D 12:58:13.250 NotebookApp] Using contents: services/contents
# [D 12:58:13.303 NotebookApp] Path base/images/favicon.ico served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/base/images/favicon.ico
# [D 12:58:13.304 NotebookApp] Path components/jquery-ui/themes/smoothness/jquery-ui.min.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/jquery-ui/themes/smoothness/jquery-ui.min.css
# [D 12:58:13.304 NotebookApp] Path components/jquery-typeahead/dist/jquery.typeahead.min.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/jquery-typeahead/dist/jquery.typeahead.min.css
# [D 12:58:13.304 NotebookApp] Path style/style.min.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/style/style.min.css
# [D 12:58:13.305 NotebookApp] Path components/es6-promise/promise.min.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/es6-promise/promise.min.js
# [D 12:58:13.306 NotebookApp] Path components/react/react.production.min.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/react/react.production.min.js
# [D 12:58:13.306 NotebookApp] Path components/react/react-dom.production.min.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/react/react-dom.production.min.js
# [D 12:58:13.306 NotebookApp] Path components/create-react-class/index.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/create-react-class/index.js
# [D 12:58:13.307 NotebookApp] Path components/requirejs/require.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/requirejs/require.js
# [D 12:58:13.308 NotebookApp] Path base/images/logo.png served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/base/images/logo.png
# [D 12:58:13.308 NotebookApp] Path tree/js/main.min.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/tree/js/main.min.js
# [D 12:58:13.312 NotebookApp] 200 GET /tree?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705 (::1) 72.150000ms
# [D 12:58:13.320 NotebookApp] Path custom.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/custom/custom.css
# [D 12:58:13.321 NotebookApp] 200 GET /custom/custom.css (::1) 2.500000ms
# [D 12:58:13.374 NotebookApp] Path services/contents.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/services/contents.js
# [D 12:58:13.374 NotebookApp] 200 GET /static/services/contents.js?v=20220510125811 (::1) 1.140000ms
# [D 12:58:13.390 NotebookApp] Paths used for configuration of tree:
#     	/etc/jupyter/nbconfig/tree.json
# [D 12:58:13.390 NotebookApp] Paths used for configuration of tree:
#     	/usr/local/etc/jupyter/nbconfig/tree.json
# [D 12:58:13.391 NotebookApp] Paths used for configuration of tree:
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/tree.json
# [D 12:58:13.391 NotebookApp] Paths used for configuration of tree:
#     	/Users/dashakaravaieva/.jupyter/nbconfig/tree.json
# [D 12:58:13.391 NotebookApp] 200 GET /api/config/tree?_=1652158693359 (::1) 2.760000ms
# [D 12:58:13.393 NotebookApp] Paths used for configuration of common:
#     	/etc/jupyter/nbconfig/common.json
# [D 12:58:13.393 NotebookApp] Paths used for configuration of common:
#     	/usr/local/etc/jupyter/nbconfig/common.json
# [D 12:58:13.393 NotebookApp] Paths used for configuration of common:
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/common.json
# [D 12:58:13.393 NotebookApp] Paths used for configuration of common:
#     	/Users/dashakaravaieva/.jupyter/nbconfig/common.json
# [D 12:58:13.393 NotebookApp] 200 GET /api/config/common?_=1652158693360 (::1) 1.690000ms
# [D 12:58:13.394 NotebookApp] 200 GET /api/terminals?_=1652158693361 (::1) 1.560000ms
# [D 12:58:13.396 NotebookApp] 200 GET /api/sessions?_=1652158693362 (::1) 2.190000ms
# [D 12:58:13.397 NotebookApp] 200 GET /api/terminals?_=1652158693363 (::1) 2.100000ms
# [D 12:58:13.397 NotebookApp] Found kernel python3101jvsc74a57bd0aee8b7b246df8f9039afb4144a1f6fd8d2ca17a180786b69acc140d282b71a49 in /Users/dashakaravaieva/Library/Jupyter/kernels
# [D 12:58:13.397 NotebookApp] Found kernel python397jvsc74a57bd0dc6f4a75986d9cb445a60b0b5fb7af2ab995ae49c603620b49c9876ed0e072b0 in /Users/dashakaravaieva/Library/Jupyter/kernels
# [D 12:58:13.397 NotebookApp] Found kernel python3 in /Users/dashakaravaieva/opt/anaconda3/share/jupyter/kernels
# [D 12:58:13.586 NotebookApp] 304 GET /api/kernelspecs (::1) 190.880000ms
# [D 12:58:13.588 NotebookApp] 200 GET /api/contents?type=directory&_=1652158693364 (::1) 1.950000ms
# [D 12:58:13.589 NotebookApp] Path custom.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/custom/custom.js
# [D 12:58:13.589 NotebookApp] 200 GET /custom/custom.js?v=20220510125811 (::1) 2.420000ms
# [D 12:58:17.284 NotebookApp] Using contents: services/contents
# [D 12:58:17.339 NotebookApp] Path base/images/favicon-notebook.ico served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/base/images/favicon-notebook.ico
# [D 12:58:17.339 NotebookApp] Path components/bootstrap-tour/build/css/bootstrap-tour.min.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/bootstrap-tour/build/css/bootstrap-tour.min.css
# [D 12:58:17.340 NotebookApp] Path components/codemirror/lib/codemirror.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/codemirror/lib/codemirror.css
# [D 12:58:17.340 NotebookApp] Path notebook/css/override.css served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/notebook/css/override.css
# [D 12:58:17.796 NotebookApp] Path components/text-encoding/lib/encoding.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/text-encoding/lib/encoding.js
# [D 12:58:17.797 NotebookApp] Path notebook/js/main.min.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/notebook/js/main.min.js
# [D 12:58:17.802 NotebookApp] 200 GET /notebooks/vgg16.ipynb (::1) 520.080000ms
# [D 12:58:17.819 NotebookApp] Path components/MathJax/MathJax.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/MathJax.js
# [D 12:58:17.819 NotebookApp] 304 GET /static/components/MathJax/MathJax.js?config=TeX-AMS-MML_HTMLorMML-full,Safe&delayStartupUntil=configured (::1) 0.760000ms
# [D 12:58:17.821 NotebookApp] 304 GET /custom/custom.css (::1) 0.640000ms
# [D 12:58:17.826 NotebookApp] Path components/MathJax/config/TeX-AMS-MML_HTMLorMML-full.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/config/TeX-AMS-MML_HTMLorMML-full.js
# [D 12:58:17.827 NotebookApp] 304 GET /static/components/MathJax/config/TeX-AMS-MML_HTMLorMML-full.js?V=2.7.9 (::1) 0.890000ms
# [D 12:58:17.907 NotebookApp] Path components/MathJax/config/Safe.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/config/Safe.js
# [D 12:58:17.907 NotebookApp] 200 GET /static/components/MathJax/config/Safe.js?V=2.7.9 (::1) 1.100000ms
# [D 12:58:17.969 NotebookApp] Paths used for configuration of notebook:
#     	/etc/jupyter/nbconfig/notebook.json
# [D 12:58:17.970 NotebookApp] Paths used for configuration of notebook:
#     	/usr/local/etc/jupyter/nbconfig/notebook.json
# [D 12:58:17.970 NotebookApp] Paths used for configuration of notebook:
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/notebook.d/catboost-widget.json
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/notebook.d/pydeck.json
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/notebook.json
# [D 12:58:17.971 NotebookApp] Paths used for configuration of notebook:
#     	/Users/dashakaravaieva/.jupyter/nbconfig/notebook.json
# [D 12:58:17.971 NotebookApp] 200 GET /api/config/notebook?_=1652158697887 (::1) 2.380000ms
# [D 12:58:17.972 NotebookApp] Paths used for configuration of common:
#     	/etc/jupyter/nbconfig/common.json
# [D 12:58:17.972 NotebookApp] Paths used for configuration of common:
#     	/usr/local/etc/jupyter/nbconfig/common.json
# [D 12:58:17.973 NotebookApp] Paths used for configuration of common:
#     	/Users/dashakaravaieva/opt/anaconda3/etc/jupyter/nbconfig/common.json
# [D 12:58:17.973 NotebookApp] Paths used for configuration of common:
#     	/Users/dashakaravaieva/.jupyter/nbconfig/common.json
# [D 12:58:17.973 NotebookApp] 200 GET /api/config/common?_=1652158697888 (::1) 1.780000ms
# [D 12:58:17.981 NotebookApp] Path components/MathJax/extensions/TeX/begingroup.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/extensions/TeX/begingroup.js
# [D 12:58:17.982 NotebookApp] 304 GET /static/components/MathJax/extensions/TeX/begingroup.js?V=2.7.9 (::1) 0.790000ms
# [D 12:58:17.982 NotebookApp] Path components/MathJax/extensions/TeX/newcommand.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/extensions/TeX/newcommand.js
# [D 12:58:17.983 NotebookApp] 304 GET /static/components/MathJax/extensions/TeX/newcommand.js?V=2.7.9 (::1) 0.880000ms
# [D 12:58:17.983 NotebookApp] Path components/MathJax/extensions/MathML/content-mathml.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/extensions/MathML/content-mathml.js
# [D 12:58:17.983 NotebookApp] 304 GET /static/components/MathJax/extensions/MathML/content-mathml.js?V=2.7.9 (::1) 0.990000ms
# [D 12:58:17.996 NotebookApp] Found kernel python3101jvsc74a57bd0aee8b7b246df8f9039afb4144a1f6fd8d2ca17a180786b69acc140d282b71a49 in /Users/dashakaravaieva/Library/Jupyter/kernels
# [D 12:58:17.996 NotebookApp] Found kernel python397jvsc74a57bd0dc6f4a75986d9cb445a60b0b5fb7af2ab995ae49c603620b49c9876ed0e072b0 in /Users/dashakaravaieva/Library/Jupyter/kernels
# [D 12:58:17.997 NotebookApp] Found kernel python3 in /Users/dashakaravaieva/opt/anaconda3/share/jupyter/kernels
# [D 12:58:17.999 NotebookApp] 304 GET /api/kernelspecs (::1) 4.440000ms
# [D 12:58:18.018 NotebookApp] 200 GET /api/contents/vgg16.ipynb?type=notebook&_=1652158697889 (::1) 14.880000ms
# [D 12:58:18.536 NotebookApp] Starting kernel: ['/Users/dashakaravaieva/opt/anaconda3/bin/python', '-m', 'ipykernel_launcher', '-f', '/Users/dashakaravaieva/Library/Jupyter/runtime/kernel-532f1b0d-ce40-46bb-a4c1-ad0c26caa808.json']
# [D 12:58:18.545 NotebookApp] Connecting to: tcp://127.0.0.1:57246
# [D 12:58:18.546 NotebookApp] Connecting to: tcp://127.0.0.1:57243
# [I 12:58:18.548 NotebookApp] Kernel started: 532f1b0d-ce40-46bb-a4c1-ad0c26caa808, name: python3
# [D 12:58:18.548 NotebookApp] Kernel args: {'kernel_name': 'python3', 'cwd': '/Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2'}
# [D 12:58:18.551 NotebookApp] 200 GET /api/contents/vgg16.ipynb/checkpoints?_=1652158697890 (::1) 2.670000ms
# [D 12:58:18.551 NotebookApp] Serving kernel resource from: /Users/dashakaravaieva/opt/anaconda3/share/jupyter/kernels/python3
# [D 12:58:18.552 NotebookApp] 304 GET /kernelspecs/python3/logo-64x64.png (::1) 3.390000ms
# [D 12:58:18.553 NotebookApp] 201 POST /api/sessions (::1) 61.380000ms
# [D 12:58:18.555 NotebookApp] 304 GET /custom/custom.js?v=20220510125811 (::1) 2.100000ms
# [D 12:58:18.555 NotebookApp] Path components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/fontdata.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/fontdata.js
# [D 12:58:18.555 NotebookApp] 304 GET /static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/fontdata.js?V=2.7.9 (::1) 2.200000ms
# [D 12:58:18.555 NotebookApp] Path catboost-widget/extension.js served from /Users/dashakaravaieva/opt/anaconda3/share/jupyter/nbextensions/catboost-widget/extension.js
# [D 12:58:18.556 NotebookApp] 200 GET /nbextensions/catboost-widget/extension.js?v=20220510125811 (::1) 2.670000ms
# [D 12:58:18.556 NotebookApp] Using contents: services/contents
# [W 12:58:18.561 NotebookApp] 404 GET /nbextensions/pydeck/extension.js?v=20220510125811 (::1) 7.240000ms referer=http://localhost:8889/notebooks/vgg16.ipynb
# [D 12:58:18.562 NotebookApp] Path jupyter-js-widgets/extension.js served from /Users/dashakaravaieva/opt/anaconda3/share/jupyter/nbextensions/jupyter-js-widgets/extension.js
# [D 12:58:18.562 NotebookApp] 200 GET /nbextensions/jupyter-js-widgets/extension.js?v=20220510125811 (::1) 8.100000ms
# [D 12:58:18.566 NotebookApp] Initializing websocket connection /api/kernels/532f1b0d-ce40-46bb-a4c1-ad0c26caa808/channels
# [D 12:58:18.567 NotebookApp] Requesting kernel info from 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:18.567 NotebookApp] Connecting to: tcp://127.0.0.1:57242
# [D 12:58:18.632 NotebookApp] Path components/MathJax/extensions/Safe.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/extensions/Safe.js
# [D 12:58:18.632 NotebookApp] 304 GET /static/components/MathJax/extensions/Safe.js?V=2.7.9 (::1) 0.730000ms
# [D 12:58:18.718 NotebookApp] Using contents: services/contents
# [W 12:58:18.718 NotebookApp] 404 GET /nbextensions/widgets/notebook/js/extension.js?v=20220510125811 (::1) 1.170000ms referer=http://localhost:8889/notebooks/vgg16.ipynb
# [D 12:58:18.838 NotebookApp] Path components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Italic/Main.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Italic/Main.js
# [D 12:58:18.838 NotebookApp] 304 GET /static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Italic/Main.js?V=2.7.9 (::1) 0.870000ms
# [D 12:58:18.885 NotebookApp] Path components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Normal/Italic/Main.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Normal/Italic/Main.js
# [D 12:58:18.886 NotebookApp] 304 GET /static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Normal/Italic/Main.js?V=2.7.9 (::1) 0.880000ms
# [D 12:58:18.941 NotebookApp] Path components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Normal-Italic.woff served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Normal-Italic.woff
# [D 12:58:18.941 NotebookApp] 200 GET /static/components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Normal-Italic.woff?V=2.7.9 (::1) 1.140000ms
# [D 12:58:18.985 NotebookApp] Path components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Regular/Main.js served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Regular/Main.js
# [D 12:58:18.986 NotebookApp] 200 GET /static/components/MathJax/jax/output/HTML-CSS/fonts/STIX-Web/Main/Regular/Main.js?V=2.7.9 (::1) 1.190000ms
# [D 12:58:19.059 NotebookApp] Path components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Main-Regular.woff served from /Users/dashakaravaieva/opt/anaconda3/lib/python3.9/site-packages/notebook/static/components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Main-Regular.woff
# [D 12:58:19.059 NotebookApp] 304 GET /static/components/MathJax/fonts/HTML-CSS/STIX-Web/woff/STIXMathJax_Main-Regular.woff?V=2.7.9 (::1) 0.810000ms
# [D 12:58:19.089 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (starting)
# [D 12:58:19.191 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (busy)
# [D 12:58:19.191 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (idle)
# [D 12:58:19.192 NotebookApp] Received kernel info: {'status': 'ok', 'protocol_version': '5.3', 'implementation': 'ipython', 'implementation_version': '7.29.0', 'language_info': {'name': 'python', 'version': '3.9.7', 'mimetype': 'text/x-python', 'codemirror_mode': {'name': 'ipython', 'version': 3}, 'pygments_lexer': 'ipython3', 'nbconvert_exporter': 'python', 'file_extension': '.py'}, 'banner': "Python 3.9.7 (default, Sep 16 2021, 08:50:36) \nType 'copyright', 'credits' or 'license' for more information\nIPython 7.29.0 -- An enhanced Interactive Python. Type '?' for help.\n", 'help_links': [{'text': 'Python Reference', 'url': 'https://docs.python.org/3.9'}, {'text': 'IPython Reference', 'url': 'https://ipython.org/documentation.html'}, {'text': 'NumPy Reference', 'url': 'https://docs.scipy.org/doc/numpy/reference/'}, {'text': 'SciPy Reference', 'url': 'https://docs.scipy.org/doc/scipy/reference/'}, {'text': 'Matplotlib Reference', 'url': 'https://matplotlib.org/contents.html'}, {'text': 'SymPy Reference', 'url': 'http://docs.sympy.org/latest/index.html'}, {'text': 'pandas Reference', 'url': 'https://pandas.pydata.org/pandas-docs/stable/'}]}
# [D 12:58:19.192 NotebookApp] 101 GET /api/kernels/532f1b0d-ce40-46bb-a4c1-ad0c26caa808/channels?session_id=dc1218f980e8450ab01556aef5409b53 (::1) 626.500000ms
# [D 12:58:19.193 NotebookApp] Opening websocket /api/kernels/532f1b0d-ce40-46bb-a4c1-ad0c26caa808/channels
# [D 12:58:19.193 NotebookApp] Getting buffer for 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.193 NotebookApp] Connecting to: tcp://127.0.0.1:57243
# [D 12:58:19.193 NotebookApp] Connecting to: tcp://127.0.0.1:57242
# [D 12:58:19.193 NotebookApp] Connecting to: tcp://127.0.0.1:57246
# [D 12:58:19.194 NotebookApp] Connecting to: tcp://127.0.0.1:57244
# [D 12:58:19.194 NotebookApp] Connecting to: tcp://127.0.0.1:57242
# [D 12:58:19.195 NotebookApp] Nudge: attempt 1 on kernel 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.197 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (busy)
# [D 12:58:19.197 NotebookApp] Nudge: IOPub received: 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.197 NotebookApp] Nudge: resolving iopub future: 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.197 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (idle)
# [D 12:58:19.198 NotebookApp] Nudge: shell info reply received: 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.198 NotebookApp] Nudge: resolving shell future: 532f1b0d-ce40-46bb-a4c1-ad0c26caa808
# [D 12:58:19.200 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (busy)
# [D 12:58:19.201 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (idle)
# [D 12:58:19.202 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (busy)
# [D 12:58:19.203 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (idle)
# [D 12:58:26.083 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: status (busy)
# [D 12:58:26.084 NotebookApp] activity on 532f1b0d-ce40-46bb-a4c1-ad0c26caa808: execute_input
# [I 12:58:27.546 NotebookApp] KernelRestarter: restarting kernel (1/5), keep random ports
# kernel 532f1b0d-ce40-46bb-a4c1-ad0c26caa808 restarted
# [D 12:58:27.548 NotebookApp] Starting kernel: ['/Users/dashakaravaieva/opt/anaconda3/bin/python', '-m', 'ipykernel_launcher', '-f', '/Users/dashakaravaieva/Library/Jupyter/runtime/kernel-532f1b0d-ce40-46bb-a4c1-ad0c26caa808.json']
# [D 12:58:27.565 NotebookApp] Connecting to: tcp://127.0.0.1:57246
# [D 12:58:30.566 NotebookApp] KernelRestarter: restart apparently succeeded
# [D 12:58:32.033 NotebookApp] 200 GET /api/sessions?_=1652158693365 (::1) 4.200000ms
# [D 12:58:32.035 NotebookApp] 200 GET /api/terminals?_=1652158693366 (::1) 1.780000ms
# [D 12:58:32.047 NotebookApp] 200 GET /api/contents?type=directory&_=1652158693367 (::1) 7.750000ms
# [D 12:58:54.500 NotebookApp] 200 GET /api/sessions?_=1652158693368 (::1) 3.780000ms
# [D 12:58:54.505 NotebookApp] 200 GET /api/terminals?_=1652158693369 (::1) 3.620000ms
# [D 12:58:54.521 NotebookApp] 200 GET /api/contents?type=directory&_=1652158693370 (::1) 7.380000ms
# ^C
# [I 12:59:18.749 NotebookApp] interrupted
# Serving notebooks from local directory: /Users/dashakaravaieva/Documents/Яндекс/курс 5/week 2
# 1 active kernel
# Jupyter Notebook 6.4.5 is running at:
# http://localhost:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
#  or http://127.0.0.1:8889/?token=2b48bb684b4b562a40fa5191ca207bd015c72d382023c705
# Shutdown this notebook server (y/[n])? resuming operation...

# %%
conda install nomkl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::dask-core==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::python-slugify==5.0.2=pyhd3eb1b0_0
#   - defaults/noarch::qtpy==1.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::llvmlite==0.37.0=py39he4411ff_1
#   - defaults/noarch::networkx==2.6.3=pyhd3eb1b0_0
#   - defaults/osx-64::unicodecsv==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::daal4py==2021.3.0=py39h01d92e1_0
#   - defaults/noarch::xmltodict==0.12.0=pyhd3eb1b0_0
#   - defaults/osx-64::mpmath==1.2.1=py39hecd8cb5_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::jedi==0.18.0=py39hecd8cb5_1
#   - defaults/osx-64::scikit-learn==0.24.2=py39hb2f4e1b_0
#   - defaults/osx-64::bitarray==2.3.0=py39h9ed2024_1
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/noarch::yapf==0.31.0=pyhd3eb1b0_0
#   - defaults/noarch::poyo==0.5.0=pyhd3eb1b0_0
#   - defaults/osx-64::mkl-service==2.4.0=py39h9ed2024_0
#   - defaults/noarch::pycodestyle==2.7.0=pyhd3eb1b0_0
#   - defaults/osx-64::pysocks==1.7.1=py39hecd8cb5_0
#   - defaults/noarch::py==1.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::pandocfilters==1.4.3=py39hecd8cb5_1
#   - defaults/noarch::qdarkstyle==3.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::typed-ast==1.4.3=py39h9ed2024_1
#   - defaults/osx-64::lightgbm==3.2.1=py39h23ab428_0
#   - defaults/noarch::alabaster==0.7.12=pyhd3eb1b0_0
#   - defaults/osx-64::webencodings==0.5.1=py39hecd8cb5_1
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/osx-64::kiwisolver==1.3.1=py39h23ab428_0
#   - defaults/osx-64::mistune==0.8.4=py39h9ed2024_1000
#   - defaults/osx-64::astroid==2.6.6=py39hecd8cb5_0
#   - defaults/noarch::importlib_metadata==4.8.1=hd3eb1b0_0
#   - defaults/osx-64::get_terminal_size==1.0.0=h7520d66_0
#   - defaults/osx-64::navigator-updater==0.2.1=py39hecd8cb5_0
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/noarch::backports==1.0=pyhd3eb1b0_2
#   - defaults/noarch::threadpoolctl==2.2.0=pyh0d69192_0
#   - defaults/osx-64::tbb4py==2021.4.0=py39haf03e11_0
#   - defaults/noarch::click==8.0.3=pyhd3eb1b0_0
#   - defaults/noarch::sortedcontainers==2.4.0=pyhd3eb1b0_0
#   - defaults/noarch::path.py==12.5.0=hd3eb1b0_0
#   - defaults/noarch::fsspec==2021.8.1=pyhd3eb1b0_0
#   - defaults/osx-64::numba==0.54.1=py39hae1ba45_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/osx-64::brotlipy==0.7.0=py39h9ed2024_1003
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::munkres==1.1.4=py_0
#   - defaults/osx-64::lazy-object-proxy==1.6.0=py39h9ed2024_0
#   - defaults/noarch::isort==5.9.3=pyhd3eb1b0_0
#   - defaults/noarch::itsdangerous==2.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::gevent==21.8.0=py39h9ed2024_1
#   - defaults/osx-64::bottleneck==1.3.2=py39he3068b8_1
#   - defaults/osx-64::xlwings==0.24.9=py39hecd8cb5_0
#   - defaults/noarch::slicer==0.0.7=pyhd3eb1b0_0
#   - defaults/osx-64::msgpack-python==1.0.2=py39hf7b0b51_1
#   - defaults/osx-64::pyzmq==22.2.1=py39h23ab428_1
#   - defaults/osx-64::fastcache==1.1.0=py39h9ed2024_0
#   - defaults/osx-64::pkginfo==1.7.1=py39hecd8cb5_0
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-64::debugpy==1.4.1=py39h23ab428_0
#   - defaults/noarch::xlsxwriter==3.0.1=pyhd3eb1b0_0
#   - defaults/noarch::idna==3.2=pyhd3eb1b0_0
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/osx-64::pyyaml==6.0=py39hca72f7f_1
#   - defaults/osx-64::zope.event==4.5.0=py39hecd8cb5_0
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/osx-64::sympy==1.9=py39hecd8cb5_0
#   - defaults/noarch::decorator==5.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::multipledispatch==0.6.0=py39hecd8cb5_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/osx-64::wrapt==1.12.1=py39h9ed2024_1
#   - defaults/osx-64::python.app==3=py39hca72f7f_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/noarch::jdcal==1.4.1=pyhd3eb1b0_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39ha952a84_0
#   - defaults/noarch::nose==1.3.7=pyhd3eb1b0_1006
#   - defaults/noarch::binaryornot==0.4.4=pyhd3eb1b0_1
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.4.1=py39hecd8cb5_1
#   - defaults/osx-64::pluggy==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::locket==0.2.1=py39hecd8cb5_1
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::openpyxl==3.0.9=pyhd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::appscript==1.1.2=py39h9ed2024_0
#   - defaults/osx-64::lxml==4.6.3=py39h26b266a_0
#   - defaults/noarch::jupyter_client==6.1.12=pyhd3eb1b0_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/osx-64::gmpy2==2.0.8=py39h4b98818_3
#   - defaults/noarch::pytz==2021.3=pyhd3eb1b0_0
#   - defaults/osx-64::cffi==1.14.6=py39h2125817_0
#   - defaults/osx-64::pyjwt==2.1.0=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib-base==3.4.3=py39h0a11d32_0
#   - defaults/osx-64::catboost==0.26.1=py39hecd8cb5_0
#   - defaults/osx-64::boto==2.49.0=py39hecd8cb5_0
#   - defaults/osx-64::path==16.0.0=py39hecd8cb5_0
#   - defaults/noarch::urllib3==1.26.7=pyhd3eb1b0_0
#   - defaults/osx-64::markupsafe==1.1.1=py39h9ed2024_0
#   - defaults/noarch::backports.tempfile==1.0=pyhd3eb1b0_1
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::regex==2021.8.3=py39h9ed2024_0
#   - defaults/noarch::jinja2==2.11.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-content-trust==0.1.1=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::importlib-metadata==4.8.1=py39hecd8cb5_0
#   - defaults/osx-64::inflection==0.5.1=py39hecd8cb5_0
#   - defaults/noarch::whichcraft==0.6.1=pyhd3eb1b0_0
#   - defaults/osx-64::wurlitzer==2.1.1=py39hecd8cb5_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/noarch::fonttools==4.25.0=pyhd3eb1b0_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_0
#   - defaults/noarch::pathspec==0.7.0=py_0
#   - defaults/osx-64::simplegeneric==0.8.1=py39hecd8cb5_2
#   - defaults/noarch::parso==0.8.2=pyhd3eb1b0_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_0
#   - defaults/noarch::singledispatch==3.7.0=pyhd3eb1b0_1001
#   - defaults/noarch::cached-property==1.5.2=py_0
#   - defaults/osx-64::argh==0.26.2=py39hecd8cb5_0
#   - defaults/noarch::dataclasses==0.8=pyh6d0b6a4_7
#   - defaults/noarch::traitlets==5.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::numpy==1.20.3=py39h4b4dc7a_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::xgboost==1.5.0=py39hecd8cb5_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::ply==3.11=py39hecd8cb5_0
#   - defaults/osx-64::greenlet==1.1.1=py39h23ab428_0
#   - defaults/noarch::snowballstemmer==2.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::shap==0.39.0=py39hb2f4e1b_0
#   - defaults/osx-64::argon2-cffi==20.1.0=py39h9ed2024_1
#   - defaults/noarch::text-unidecode==1.3=pyhd3eb1b0_0
#   - defaults/osx-64::cycler==0.10.0=py39hecd8cb5_0
#   - defaults/noarch::pyflakes==2.3.1=pyhd3eb1b0_0
#   - defaults/noarch::tblib==1.7.0=pyhd3eb1b0_0
#   - defaults/osx-64::keyring==23.1.0=py39hecd8cb5_0
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::typing_extensions==3.10.0.2=pyh06a4308_0
#   - defaults/osx-64::ujson==4.0.2=py39h23ab428_0
#   - defaults/noarch::diff-match-patch==20200713=pyhd3eb1b0_0
#   - defaults/osx-64::pip==21.2.4=py39hecd8cb5_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::spyder-kernels==2.1.3=py39hecd8cb5_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/osx-64::pywavelets==1.1.1=py39he3068b8_4
#   - defaults/noarch::unidecode==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-64::certifi==2021.10.8=py39hecd8cb5_0
#   - defaults/noarch::prompt_toolkit==3.0.20=hd3eb1b0_0
#   - defaults/noarch::xlrd==2.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::xlwt==1.3.0=py39hecd8cb5_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::packaging==21.0=pyhd3eb1b0_0
#   - defaults/osx-64::pyodbc==4.0.31=py39h23ab428_0
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/noarch::async_generator==1.10=pyhd3eb1b0_0
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/noarch::flake8==3.9.2=pyhd3eb1b0_0
#   - defaults/osx-64::rtree==0.9.7=py39hecd8cb5_1
#   - defaults/osx-64::python==3.9.7=h88f2d9e_1
#   - defaults/noarch::attrs==21.2.0=pyhd3eb1b0_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/noarch::html5lib==1.1=pyhd3eb1b0_0
#   - defaults/noarch::mock==4.0.3=pyhd3eb1b0_0
#   - defaults/noarch::requests==2.26.0=pyhd3eb1b0_0
#   - defaults/osx-64::pytest==6.2.4=py39hecd8cb5_2
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/noarch::textdistance==4.2.1=pyhd3eb1b0_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/noarch::qtawesome==1.0.2=pyhd3eb1b0_0
#   - defaults/noarch::more-itertools==8.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::watchdog==2.1.3=py39hd5f6b7e_0
#   - defaults/osx-64::psutil==5.8.0=py39h9ed2024_1
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/noarch::bleach==4.0.0=pyhd3eb1b0_0
#   - defaults/osx-64::h5py==3.2.1=py39h90fc2a2_0
#   - defaults/osx-64::arrow==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::anyio==2.2.0=py39hecd8cb5_1
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=pyhd3eb1b0_0
#   - defaults/noarch::cloudpickle==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyter_console==6.4.0=pyhd3eb1b0_0
#   - defaults/noarch::three-merge==0.1.1=pyhd3eb1b0_0
#   - defaults/noarch::python-lsp-jsonrpc==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/noarch::matplotlib-inline==0.1.2=pyhd3eb1b0_2
#   - defaults/osx-64::zope.interface==5.4.0=py39h9ed2024_0
#   - defaults/noarch::qstylizer==0.1.10=pyhd3eb1b0_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::pyqt==5.9.2=py39h23ab428_6
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::pydocstyle==6.1.1=pyhd3eb1b0_0
#   - defaults/noarch::glob2==0.7=pyhd3eb1b0_0
#   - defaults/noarch::backports.shutil_get_terminal_size==1.0.0=pyhd3eb1b0_3
#   - defaults/noarch::toolz==0.11.1=pyhd3eb1b0_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/osx-64::setuptools==58.0.4=py39hecd8cb5_0
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/noarch::pygments==2.10.0=pyhd3eb1b0_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::qtconsole==5.1.1=pyhd3eb1b0_0
#   - defaults/noarch::prompt-toolkit==3.0.20=pyhd3eb1b0_0
#   - defaults/noarch::contextlib2==0.6.0.post1=pyhd3eb1b0_0
#   - defaults/noarch::pyopenssl==21.0.0=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_core==4.8.1=py39hecd8cb5_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/osx-64::ipython==7.29.0=py39h01d92e1_0
#   - defaults/noarch::heapdict==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::appdirs==1.4.4=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/noarch::tinycss==0.4=pyhd3eb1b0_1002
#   - defaults/noarch::filelock==3.3.1=pyhd3eb1b0_1
#   - defaults/osx-64::pylint==2.9.6=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.5=pyhd3eb1b0_0
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/osx-64::pillow==8.4.0=py39h98e4679_0
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/noarch::beautifulsoup4==4.10.0=pyh06a4308_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/osx-64::numexpr==2.7.3=py39h5873af2_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::py-xgboost==1.5.0=py39hecd8cb5_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/osx-64::pyrsistent==0.18.0=py39hca72f7f_0
#   - defaults/noarch::intervaltree==3.1.0=pyhd3eb1b0_0
#   - defaults/noarch::werkzeug==2.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::sphinxcontrib==1.0=py39hecd8cb5_1
#   - defaults/noarch::python-lsp-server==1.2.4=pyhd3eb1b0_0
#   - defaults/noarch::applaunchservices==0.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/noarch::python-libarchive-c==2.9=pyhd3eb1b0_1
#   - defaults/osx-64::tornado==6.1=py39h9ed2024_0
#   - defaults/osx-64::pycurl==7.44.1=py39hbcfaee0_1
#   - defaults/osx-64::pycosat==0.6.3=py39h9ed2024_0
#   - defaults/osx-64::terminado==0.9.4=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::chardet==4.0.0=py39hecd8cb5_1003
#   - defaults/osx-64::cryptography==3.4.8=py39h2fd3fbb_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::cytoolz==0.11.0=py39h9ed2024_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::pyparsing==3.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::appnope==0.1.2=py39hecd8cb5_1001
#   - defaults/noarch::sortedcollections==2.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::et_xmlfile==1.1.0=py39hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/noarch::autopep8==1.5.7=pyhd3eb1b0_0
#   - defaults/osx-64::sqlalchemy==1.4.22=py39h9ed2024_0
#   - defaults/noarch::colorama==0.4.4=pyhd3eb1b0_0
#   - defaults/osx-64::zope==1.0=py39hecd8cb5_1
#   - defaults/osx-64::cython==0.29.24=py39he9d5cce_0
#   - defaults/osx-64::mccabe==0.6.1=py39hecd8cb5_1
#   - defaults/noarch::joblib==1.1.0=pyhd3eb1b0_0
#   - defaults/noarch::olefile==0.46=pyhd3eb1b0_0
#   - defaults/noarch::prometheus_client==0.11.0=pyhd3eb1b0_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::entrypoints==0.3=py39hecd8cb5_0
#   - defaults/noarch::zipp==3.6.0=pyhd3eb1b0_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/osx-64::future==0.18.2=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::py-lief==0.10.1=py39h23ab428_1
#   - defaults/osx-64::docutils==0.17.1=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-websupport==1.2.4=py_0
#   - defaults/noarch::imagesize==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-64::ruamel_yaml==0.15.100=py39h9ed2024_0
#   - defaults/osx-64::clyent==1.2.2=py39hecd8cb5_1
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/osx-64::sniffio==1.2.0=py39hecd8cb5_1
#   - defaults/noarch::rope==0.19.0=pyhd3eb1b0_0
#   - defaults/noarch::altair==4.1.0=py_1
#   - defaults/osx-64::sip==4.19.13=py39h23ab428_0
#   - defaults/osx-64::pep8==1.7.1=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/noarch::zict==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
#   - defaults/osx-64::mypy_extensions==0.4.3=py39hecd8cb5_0
#   - defaults/osx-64::pathlib2==2.3.6=py39hecd8cb5_2
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::dask-core==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::python-slugify==5.0.2=pyhd3eb1b0_0
#   - defaults/noarch::qtpy==1.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::llvmlite==0.37.0=py39he4411ff_1
#   - defaults/noarch::networkx==2.6.3=pyhd3eb1b0_0
#   - defaults/osx-64::unicodecsv==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::daal4py==2021.3.0=py39h01d92e1_0
#   - defaults/noarch::xmltodict==0.12.0=pyhd3eb1b0_0
#   - defaults/osx-64::mpmath==1.2.1=py39hecd8cb5_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::jedi==0.18.0=py39hecd8cb5_1
#   - defaults/osx-64::scikit-learn==0.24.2=py39hb2f4e1b_0
#   - defaults/osx-64::bitarray==2.3.0=py39h9ed2024_1
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/noarch::yapf==0.31.0=pyhd3eb1b0_0
#   - defaults/noarch::poyo==0.5.0=pyhd3eb1b0_0
#   - defaults/osx-64::mkl-service==2.4.0=py39h9ed2024_0
#   - defaults/noarch::pycodestyle==2.7.0=pyhd3eb1b0_0
#   - defaults/osx-64::pysocks==1.7.1=py39hecd8cb5_0
#   - defaults/noarch::py==1.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::pandocfilters==1.4.3=py39hecd8cb5_1
#   - defaults/noarch::qdarkstyle==3.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::typed-ast==1.4.3=py39h9ed2024_1
#   - defaults/osx-64::lightgbm==3.2.1=py39h23ab428_0
#   - defaults/noarch::alabaster==0.7.12=pyhd3eb1b0_0
#   - defaults/osx-64::webencodings==0.5.1=py39hecd8cb5_1
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/osx-64::kiwisolver==1.3.1=py39h23ab428_0
#   - defaults/osx-64::mistune==0.8.4=py39h9ed2024_1000
#   - defaults/osx-64::astroid==2.6.6=py39hecd8cb5_0
#   - defaults/noarch::importlib_metadata==4.8.1=hd3eb1b0_0
#   - defaults/osx-64::get_terminal_size==1.0.0=h7520d66_0
#   - defaults/osx-64::navigator-updater==0.2.1=py39hecd8cb5_0
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/noarch::backports==1.0=pyhd3eb1b0_2
#   - defaults/noarch::threadpoolctl==2.2.0=pyh0d69192_0
#   - defaults/osx-64::tbb4py==2021.4.0=py39haf03e11_0
#   - defaults/noarch::click==8.0.3=pyhd3eb1b0_0
#   - defaults/noarch::sortedcontainers==2.4.0=pyhd3eb1b0_0
#   - defaults/noarch::path.py==12.5.0=hd3eb1b0_0
#   - defaults/noarch::fsspec==2021.8.1=pyhd3eb1b0_0
#   - defaults/osx-64::numba==0.54.1=py39hae1ba45_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/osx-64::brotlipy==0.7.0=py39h9ed2024_1003
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::munkres==1.1.4=py_0
#   - defaults/osx-64::lazy-object-proxy==1.6.0=py39h9ed2024_0
#   - defaults/noarch::isort==5.9.3=pyhd3eb1b0_0
#   - defaults/noarch::itsdangerous==2.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::gevent==21.8.0=py39h9ed2024_1
#   - defaults/osx-64::bottleneck==1.3.2=py39he3068b8_1
#   - defaults/osx-64::xlwings==0.24.9=py39hecd8cb5_0
#   - defaults/noarch::slicer==0.0.7=pyhd3eb1b0_0
#   - defaults/osx-64::msgpack-python==1.0.2=py39hf7b0b51_1
#   - defaults/osx-64::pyzmq==22.2.1=py39h23ab428_1
#   - defaults/osx-64::fastcache==1.1.0=py39h9ed2024_0
#   - defaults/osx-64::pkginfo==1.7.1=py39hecd8cb5_0
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-64::debugpy==1.4.1=py39h23ab428_0
#   - defaults/noarch::xlsxwriter==3.0.1=pyhd3eb1b0_0
#   - defaults/noarch::idna==3.2=pyhd3eb1b0_0
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/osx-64::pyyaml==6.0=py39hca72f7f_1
#   - defaults/osx-64::zope.event==4.5.0=py39hecd8cb5_0
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/osx-64::sympy==1.9=py39hecd8cb5_0
#   - defaults/noarch::decorator==5.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::multipledispatch==0.6.0=py39hecd8cb5_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/osx-64::wrapt==1.12.1=py39h9ed2024_1
#   - defaults/osx-64::python.app==3=py39hca72f7f_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/noarch::jdcal==1.4.1=pyhd3eb1b0_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39ha952a84_0
#   - defaults/noarch::nose==1.3.7=pyhd3eb1b0_1006
#   - defaults/noarch::binaryornot==0.4.4=pyhd3eb1b0_1
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.4.1=py39hecd8cb5_1
#   - defaults/osx-64::pluggy==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::locket==0.2.1=py39hecd8cb5_1
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::openpyxl==3.0.9=pyhd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::appscript==1.1.2=py39h9ed2024_0
#   - defaults/osx-64::lxml==4.6.3=py39h26b266a_0
#   - defaults/noarch::jupyter_client==6.1.12=pyhd3eb1b0_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/osx-64::gmpy2==2.0.8=py39h4b98818_3
#   - defaults/noarch::pytz==2021.3=pyhd3eb1b0_0
#   - defaults/osx-64::cffi==1.14.6=py39h2125817_0
#   - defaults/osx-64::pyjwt==2.1.0=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib-base==3.4.3=py39h0a11d32_0
#   - defaults/osx-64::catboost==0.26.1=py39hecd8cb5_0
#   - defaults/osx-64::boto==2.49.0=py39hecd8cb5_0
#   - defaults/osx-64::path==16.0.0=py39hecd8cb5_0
#   - defaults/noarch::urllib3==1.26.7=pyhd3eb1b0_0
#   - defaults/osx-64::markupsafe==1.1.1=py39h9ed2024_0
#   - defaults/noarch::backports.tempfile==1.0=pyhd3eb1b0_1
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::regex==2021.8.3=py39h9ed2024_0
#   - defaults/noarch::jinja2==2.11.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-content-trust==0.1.1=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::importlib-metadata==4.8.1=py39hecd8cb5_0
#   - defaults/osx-64::inflection==0.5.1=py39hecd8cb5_0
#   - defaults/noarch::whichcraft==0.6.1=pyhd3eb1b0_0
#   - defaults/osx-64::wurlitzer==2.1.1=py39hecd8cb5_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/noarch::fonttools==4.25.0=pyhd3eb1b0_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_0
#   - defaults/noarch::pathspec==0.7.0=py_0
#   - defaults/osx-64::simplegeneric==0.8.1=py39hecd8cb5_2
#   - defaults/noarch::parso==0.8.2=pyhd3eb1b0_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_0
#   - defaults/noarch::singledispatch==3.7.0=pyhd3eb1b0_1001
#   - defaults/noarch::cached-property==1.5.2=py_0
#   - defaults/osx-64::argh==0.26.2=py39hecd8cb5_0
#   - defaults/noarch::dataclasses==0.8=pyh6d0b6a4_7
#   - defaults/noarch::traitlets==5.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::numpy==1.20.3=py39h4b4dc7a_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::xgboost==1.5.0=py39hecd8cb5_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::ply==3.11=py39hecd8cb5_0
#   - defaults/osx-64::greenlet==1.1.1=py39h23ab428_0
#   - defaults/noarch::snowballstemmer==2.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::shap==0.39.0=py39hb2f4e1b_0
#   - defaults/osx-64::argon2-cffi==20.1.0=py39h9ed2024_1
#   - defaults/noarch::text-unidecode==1.3=pyhd3eb1b0_0
#   - defaults/osx-64::cycler==0.10.0=py39hecd8cb5_0
#   - defaults/noarch::pyflakes==2.3.1=pyhd3eb1b0_0
#   - defaults/noarch::tblib==1.7.0=pyhd3eb1b0_0
#   - defaults/osx-64::keyring==23.1.0=py39hecd8cb5_0
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::typing_extensions==3.10.0.2=pyh06a4308_0
#   - defaults/osx-64::ujson==4.0.2=py39h23ab428_0
#   - defaults/noarch::diff-match-patch==20200713=pyhd3eb1b0_0
#   - defaults/osx-64::pip==21.2.4=py39hecd8cb5_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::spyder-kernels==2.1.3=py39hecd8cb5_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/osx-64::pywavelets==1.1.1=py39he3068b8_4
#   - defaults/noarch::unidecode==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-64::certifi==2021.10.8=py39hecd8cb5_0
#   - defaults/noarch::prompt_toolkit==3.0.20=hd3eb1b0_0
#   - defaults/noarch::xlrd==2.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::xlwt==1.3.0=py39hecd8cb5_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::packaging==21.0=pyhd3eb1b0_0
#   - defaults/osx-64::pyodbc==4.0.31=py39h23ab428_0
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/noarch::async_generator==1.10=pyhd3eb1b0_0
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/noarch::flake8==3.9.2=pyhd3eb1b0_0
#   - defaults/osx-64::rtree==0.9.7=py39hecd8cb5_1
#   - defaults/osx-64::python==3.9.7=h88f2d9e_1
#   - defaults/noarch::attrs==21.2.0=pyhd3eb1b0_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/noarch::html5lib==1.1=pyhd3eb1b0_0
#   - defaults/noarch::mock==4.0.3=pyhd3eb1b0_0
#   - defaults/noarch::requests==2.26.0=pyhd3eb1b0_0
#   - defaults/osx-64::pytest==6.2.4=py39hecd8cb5_2
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/noarch::textdistance==4.2.1=pyhd3eb1b0_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/noarch::qtawesome==1.0.2=pyhd3eb1b0_0
#   - defaults/noarch::more-itertools==8.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::watchdog==2.1.3=py39hd5f6b7e_0
#   - defaults/osx-64::psutil==5.8.0=py39h9ed2024_1
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/noarch::bleach==4.0.0=pyhd3eb1b0_0
#   - defaults/osx-64::h5py==3.2.1=py39h90fc2a2_0
#   - defaults/osx-64::arrow==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::anyio==2.2.0=py39hecd8cb5_1
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=pyhd3eb1b0_0
#   - defaults/noarch::cloudpickle==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyter_console==6.4.0=pyhd3eb1b0_0
#   - defaults/noarch::three-merge==0.1.1=pyhd3eb1b0_0
#   - defaults/noarch::python-lsp-jsonrpc==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/noarch::matplotlib-inline==0.1.2=pyhd3eb1b0_2
#   - defaults/osx-64::zope.interface==5.4.0=py39h9ed2024_0
#   - defaults/noarch::qstylizer==0.1.10=pyhd3eb1b0_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::pyqt==5.9.2=py39h23ab428_6
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::pydocstyle==6.1.1=pyhd3eb1b0_0
#   - defaults/noarch::glob2==0.7=pyhd3eb1b0_0
#   - defaults/noarch::backports.shutil_get_terminal_size==1.0.0=pyhd3eb1b0_3
#   - defaults/noarch::toolz==0.11.1=pyhd3eb1b0_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/osx-64::setuptools==58.0.4=py39hecd8cb5_0
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/noarch::pygments==2.10.0=pyhd3eb1b0_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::qtconsole==5.1.1=pyhd3eb1b0_0
#   - defaults/noarch::prompt-toolkit==3.0.20=pyhd3eb1b0_0
#   - defaults/noarch::contextlib2==0.6.0.post1=pyhd3eb1b0_0
#   - defaults/noarch::pyopenssl==21.0.0=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_core==4.8.1=py39hecd8cb5_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/osx-64::ipython==7.29.0=py39h01d92e1_0
#   - defaults/noarch::heapdict==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::appdirs==1.4.4=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/noarch::tinycss==0.4=pyhd3eb1b0_1002
#   - defaults/noarch::filelock==3.3.1=pyhd3eb1b0_1
#   - defaults/osx-64::pylint==2.9.6=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.5=pyhd3eb1b0_0
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/osx-64::pillow==8.4.0=py39h98e4679_0
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/noarch::beautifulsoup4==4.10.0=pyh06a4308_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/osx-64::numexpr==2.7.3=py39h5873af2_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::py-xgboost==1.5.0=py39hecd8cb5_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/osx-64::pyrsistent==0.18.0=py39hca72f7f_0
#   - defaults/noarch::intervaltree==3.1.0=pyhd3eb1b0_0
#   - defaults/noarch::werkzeug==2.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::sphinxcontrib==1.0=py39hecd8cb5_1
#   - defaults/noarch::python-lsp-server==1.2.4=pyhd3eb1b0_0
#   - defaults/noarch::applaunchservices==0.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/noarch::python-libarchive-c==2.9=pyhd3eb1b0_1
#   - defaults/osx-64::tornado==6.1=py39h9ed2024_0
#   - defaults/osx-64::pycurl==7.44.1=py39hbcfaee0_1
#   - defaults/osx-64::pycosat==0.6.3=py39h9ed2024_0
#   - defaults/osx-64::terminado==0.9.4=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::chardet==4.0.0=py39hecd8cb5_1003
#   - defaults/osx-64::cryptography==3.4.8=py39h2fd3fbb_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::cytoolz==0.11.0=py39h9ed2024_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::pyparsing==3.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::appnope==0.1.2=py39hecd8cb5_1001
#   - defaults/noarch::sortedcollections==2.1.0=pyhd3eb1b0_0
#   - defaults/osx-64::et_xmlfile==1.1.0=py39hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/noarch::autopep8==1.5.7=pyhd3eb1b0_0
#   - defaults/osx-64::sqlalchemy==1.4.22=py39h9ed2024_0
#   - defaults/noarch::colorama==0.4.4=pyhd3eb1b0_0
#   - defaults/osx-64::zope==1.0=py39hecd8cb5_1
#   - defaults/osx-64::cython==0.29.24=py39he9d5cce_0
#   - defaults/osx-64::mccabe==0.6.1=py39hecd8cb5_1
#   - defaults/noarch::joblib==1.1.0=pyhd3eb1b0_0
#   - defaults/noarch::olefile==0.46=pyhd3eb1b0_0
#   - defaults/noarch::prometheus_client==0.11.0=pyhd3eb1b0_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::entrypoints==0.3=py39hecd8cb5_0
#   - defaults/noarch::zipp==3.6.0=pyhd3eb1b0_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/osx-64::future==0.18.2=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::py-lief==0.10.1=py39h23ab428_1
#   - defaults/osx-64::docutils==0.17.1=py39hecd8cb5_1
#   - defaults/noarch::sphinxcontrib-websupport==1.2.4=py_0
#   - defaults/noarch::imagesize==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-64::ruamel_yaml==0.15.100=py39h9ed2024_0
#   - defaults/osx-64::clyent==1.2.2=py39hecd8cb5_1
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/osx-64::sniffio==1.2.0=py39hecd8cb5_1
#   - defaults/noarch::rope==0.19.0=pyhd3eb1b0_0
#   - defaults/noarch::altair==4.1.0=py_1
#   - defaults/osx-64::sip==4.19.13=py39h23ab428_0
#   - defaults/osx-64::pep8==1.7.1=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/noarch::zict==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
#   - defaults/osx-64::mypy_extensions==0.4.3=py39hecd8cb5_0
#   - defaults/osx-64::pathlib2==2.3.6=py39hecd8cb5_2
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: - ^C
# failed
#
# CondaError: KeyboardInterrupt
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# inspired by
# http://www.cs.toronto.edu/~frossard/post/vgg16/                               
# Model from https://gist.github.com/ksimonyan/211839e770f7b538e2d8#file-readme-md     #
# Weights from Caffe converted using https://github.com/ethereon/caffe-tensorflow      #

import glob
import os
import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior() 
#import numpy as np
#from imageio import imread
#from skimage.transform import resize
#from imagenet_classes import class_names
#import sys
#from sklearn.svm import SVC

# %% [markdown]
# В этом классе содержится описание модели VGG - структура, инициализация, загрузка весов. Следует помнить - пока не запущена сессия Tensorflow, никакой реальной работы не производится.

# %%
class vgg16:
    def __init__(self, imgs, weights=None, sess=None):
        self.imgs = imgs
        self.convlayers()
        self.fc_layers()
        self.probs = tf.nn.softmax(self.fc3l)
        if weights is not None and sess is not None:
            self.load_weights(weights, sess)


    def convlayers(self):
        self.parameters = []

        # zero-mean input
        with tf.name_scope('preprocess') as scope:
            mean = tf.constant([123.68, 116.779, 103.939], dtype=tf.float32, shape=[1, 1, 1, 3], name='img_mean')
            images = self.imgs-mean

        # conv1_1
        with tf.name_scope('conv1_1') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 3, 64], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(images, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[64], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv1_1 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv1_2
        with tf.name_scope('conv1_2') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 64, 64], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv1_1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[64], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv1_2 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # pool1
        self.pool1 = tf.nn.max_pool(self.conv1_2,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME',
                               name='pool1')

        # conv2_1
        with tf.name_scope('conv2_1') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 64, 128], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.pool1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[128], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv2_1 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv2_2
        with tf.name_scope('conv2_2') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 128, 128], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv2_1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[128], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv2_2 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # pool2
        self.pool2 = tf.nn.max_pool(self.conv2_2,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME',
                               name='pool2')

        # conv3_1
        with tf.name_scope('conv3_1') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 128, 256], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.pool2, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[256], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv3_1 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv3_2
        with tf.name_scope('conv3_2') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 256, 256], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv3_1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[256], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv3_2 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv3_3
        with tf.name_scope('conv3_3') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 256, 256], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv3_2, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[256], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv3_3 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # pool3
        self.pool3 = tf.nn.max_pool(self.conv3_3,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME',
                               name='pool3')

        # conv4_1
        with tf.name_scope('conv4_1') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 256, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.pool3, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv4_1 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv4_2
        with tf.name_scope('conv4_2') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 512, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv4_1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv4_2 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv4_3
        with tf.name_scope('conv4_3') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 512, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv4_2, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv4_3 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # pool4
        self.pool4 = tf.nn.max_pool(self.conv4_3,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME',
                               name='pool4')

        # conv5_1
        with tf.name_scope('conv5_1') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 512, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.pool4, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv5_1 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv5_2
        with tf.name_scope('conv5_2') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 512, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv5_1, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv5_2 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # conv5_3
        with tf.name_scope('conv5_3') as scope:
            kernel = tf.Variable(tf.truncated_normal([3, 3, 512, 512], dtype=tf.float32,
                                                     stddev=1e-1), name='weights')
            conv = tf.nn.conv2d(self.conv5_2, kernel, [1, 1, 1, 1], padding='SAME')
            biases = tf.Variable(tf.constant(0.0, shape=[512], dtype=tf.float32),
                                 trainable=True, name='biases')
            out = tf.nn.bias_add(conv, biases)
            self.conv5_3 = tf.nn.relu(out, name=scope)
            self.parameters += [kernel, biases]

        # pool5
        self.pool5 = tf.nn.max_pool(self.conv5_3,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME',
                               name='pool4')

    def fc_layers(self):
        # fc1
        with tf.name_scope('fc1') as scope:
            shape = int(np.prod(self.pool5.get_shape()[1:]))
            fc1w = tf.Variable(tf.truncated_normal([shape, 4096],
                                                         dtype=tf.float32,
                                                         stddev=1e-1), name='weights')
            fc1b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32),
                                 trainable=True, name='biases')
            pool5_flat = tf.reshape(self.pool5, [-1, shape])
            fc1l = tf.nn.bias_add(tf.matmul(pool5_flat, fc1w), fc1b)
            self.fc1 = tf.nn.relu(fc1l)
            self.parameters += [fc1w, fc1b]

        # fc2
        with tf.name_scope('fc2') as scope:
            fc2w = tf.Variable(tf.truncated_normal([4096, 4096],
                                                         dtype=tf.float32,
                                                         stddev=1e-1), name='weights')
            fc2b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32),
                                 trainable=True, name='biases')
            fc2l = tf.nn.bias_add(tf.matmul(self.fc1, fc2w), fc2b)
            self.fc2 = tf.nn.relu(fc2l)
            self.parameters += [fc2w, fc2b]

        # fc3
        with tf.name_scope('fc3') as scope:
            fc3w = tf.Variable(tf.truncated_normal([4096, 1000],
                                                         dtype=tf.float32,
                                                         stddev=1e-1), name='weights')
            fc3b = tf.Variable(tf.constant(1.0, shape=[1000], dtype=tf.float32),
                                 trainable=True, name='biases')
            self.fc3l = tf.nn.bias_add(tf.matmul(self.fc2, fc3w), fc3b)
            self.parameters += [fc3w, fc3b]

    def load_weights(self, weight_file, sess):
        weights = np.load(weight_file)
        keys = sorted(weights.keys())
        for i, k in enumerate(keys):
            print(i, k, np.shape(weights[k]))
            sess.run(self.parameters[i].assign(weights[k]))

# %%
# Функция сохранения в файл ответа, состоящего из одного числа
def save_answerNum(fname,number):
    with open(fname,"w") as fout:
        fout.write(str(number))

# %%
# Функция сохранения в файл ответа, представленного массивом
def save_answerArray(fname,array):
    with open(fname,"w") as fout:
        fout.write(" ".join([str(el) for el in array]))

# %%
# Загрузка словаря из текстового файла. Словарь у нас используется для сохранения меток классов в выборке data.
def load_txt(fname):
    line_dict = {}
    for line in open(fname):
        fname, class_id = line.strip().split()
        line_dict[fname] = class_id

    return line_dict

# %%
# Функция обработки отдельного изображения, печатает метки TOP-5 классов и уверенность модели в каждом из них.
def process_image(fname):
    img1 = imread(fname, pilmode='RGB')
    img1 = resize(img1, (224, 224))
    
    prob = sess.run(vgg.probs, feed_dict={vgg.imgs: [img1]})[0]
    preds = (np.argsort(prob)[::-1])[0:5]
    for p in preds:
        print(class_names[p], prob[p])

# %%
# Инициируем TF сессию, и инициализируем модель. На этом шаге модель загружает веса. Веса - это 500Мб в сжатом виде
# и ~2.5Гб в памяти, процесс их загрузки послойно выводится ниже этой ячейки, и если вы увидите этот вывод ещё раз - 
# у вас неистово кончается память. Остановитесь. Также, не запускайте эту ячейку на выполнение больше одного раза
# за запуск ядра Jupyter.
sess = tf.Session()
imgs = tf.placeholder(tf.float32, [None, 224, 224, 3])
vgg = vgg16(imgs, 'vgg16_weights.npz', sess)

# %% [markdown]
# Все ячейки выше не нуждаются в модификации для выполнения задания, и необходимы к исполнению только один раз, в порядке следования. Повторный запуск ячейки с инициализацией модели будет сжирать память. Вы предупреждены.

# %% [markdown]
# ## Задание 1\.
#
# Для начала нужно запустить готовую модель `vgg16`, предобученную на `imagenet`. Модель обучена с помощью `caffe` и сконвертирована в формат `tensorflow` - `vgg16_weights.npz`. Скрипт, иллюстрирующий применение этой модели к изображению, возвращает топ-5 классов из `imagenet` и уверенность в этих классах.
#
# **Задание:** Загрузите уверенность для первого класса для изображения `train/00002.jpg` с точностью до 1 знака после запятой в файл с ответом.

# %%
# Ваш код здесь

# %%
# save_answerNum("vgg16_answer1.txt", __ )

# %% [markdown]
# ## Задание 2\.
#
# Научитесь извлекать `fc2` слой. Возьмите за основу код `process_image`, и модифицируйте, чтобы вместо последнего слоя извлекались выходы `fc2`.
#
# **Задание:** Посчитайте `fc2` для картинки `train/00002.jpg`.  Запишите первые 20 компонент.

# %%
img1 = imread('train/00002.jpg', pilmode='RGB')
img1 = resize(img1, (224, 224))

# Ваш код здесь

# %%
# save_answerArray("vgg16_answer2", __ )

# %% [markdown]
# ## Задание 3\.
#
# Теперь необходимо дообучить классификатор на нашей базе. В качестве бейзлайна предлагается воспользоваться классификатором `svm` из пакета `scipy`.
#
# - Модифицировать функцию `get_features` и добавить возможность вычислять `fc2`. (Аналогично второму заданию).
# - Применить `get_feautures`, чтобы получить `X_test` и `Y_test`.
# - Воспользоваться классификатором `SVC` с `random_state=0`.
#
# > **Важно!** Если вам не удалось поставить `tensorflow`, то необходимо вместо использования функции `get_features`, загрузить предпосчитанные `X`, `Y`, `X_test`, `Y_test` из архива: https://yadi.sk/d/RzMOK8Fjvs6Ln и воспользоваться функцией `np.load` для их загрузки, а после этого два последних пункта.
#
# **Задание:** Сколько правильных ответов получается на валидационной выборке из папки `test`? Запишите в файл.

# %%
# Функция, возвращающая признаковое описание для каждого файла jpg в заданной папке
def get_features(folder, ydict):

    paths = glob.glob(folder)
    X = np.zeros((len(paths), 4096))
    Y = np.zeros(len(paths))

    for i,img_name in enumerate(paths):
        print(img_name)
        base = os.path.basename(img_name)
        Y[i] = ydict[base]

        img1 = imread('train/00002.jpg', pilmode='RGB')
        img1 = resize(img1, (224, 224))
        # Здесь ваш код. Нужно получить слой fc2
        
        
        X[i, :] = fc2
    
    return X, Y

# %%
# Функция обработки папки. Ожидается, что в этой папке лежит файл results.txt с метками классов, и 
# имеются подразделы train и test с jpg файлами.
def process_folder(folder):
    ydict = load_txt(os.path.join(folder,'results.txt'))
    
    X, Y = get_features(os.path.join(folder, 'train/*jpg'), ydict)
    # Ваш код здесь. 
    # X_test, Y_test = 

    # Ваш код здесь. 

    
    Y_test_pred = clf.predict(X_test)
    print(sum(Y_test == Y_test_pred)) # Число правильно предсказанных классов

# %%
process_folder('.') # Вызови меня!

# %%
# save_answerNum("vgg16_answer3.txt", __ )
